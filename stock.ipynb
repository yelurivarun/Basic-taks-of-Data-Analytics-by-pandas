# %% [markdown]
# reading file

# %%
 Mini Project - Stock-Prices
Batch: Data Analytics & Data Science
Estimated Duration: 2 Days
Computer Quiz Game
Problem Statement:
LOAD
1. Use Pandas to load the data into a data frame. Display the data in the Data Frame.
2. How many non-null values exist for each column and what each column’s type is?
3. Find the number of rows and columns using the shape property and the len( ) function.
4. Display the first and last 10 rows.
ACCESS
5. Show the Company column.
6. Show the columns named Company and Industry in a Data Frame.
7. Present the information for the row that has the symbol AAPL.
8. Show the Exchange for the row with the Symbol AAPL.
FILTER
9. Sort (and show) the data by Industry, the Company.
10. Show the rows where Industry is Information Technology.
MISSING
11. Show the rows where Notes has a value (other than missing).
DROPPING
12. Create and display a Data Frame from the full Data Frame but excluding the Notes 
column.
JOIN
13. The file Stock-Prices.csv has additional data, including Symbols and Prices. Use join() to 
augment the Data Frame with the Price data.
Points:
Successful executable code: 20 MARKS
Presentation (online/offline): Additional 10 
Submission: Code in Jupiter Notebook, Report

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\hp\\Desktop\\da\\projects\\stock project\\stocks.csv')
df
# Out:
#    Symbol                   Company Exchange                        Industry  \
# 0     MMM                        3M     NYSE                    Conglomerate
# 1     AXP          American Express     NYSE              Financial services
# 2    AMGN                     Amgen   NASDAQ         Pharmaceutical industry
# 3    AAPL                Apple Inc.   NASDAQ          Information technology
# 4      BA                    Boeing     NYSE           Aerospace and defense
# 5     CAT          Caterpillar Inc.     NYSE         Construction and Mining
# 6     CVX       Chevron Corporation     NYSE              Petroleum industry
# 7    CSCO             Cisco Systems   NASDAQ          Information technology
# 8      KO     The Coca-Cola Company     NYSE                   Food industry
# 9     DOW                  Dow Inc.     NYSE               Chemical industry
# 10     GS             Goldman Sachs     NYSE              Financial services
# ...

# %%
# How many non-null values exist for each column and what each column’s type is?
df.isnull().sum()
# Out:
# Symbol              0
# Company             0
# Exchange            0
# Industry            0
# Date added          0
# Notes              26
# Index weighting     0
# dtype: int64

# %%
df.dtypes
# Out:
# Symbol             object
# Company            object
# Exchange           object
# Industry           object
# Date added         object
# Notes              object
# Index weighting    object
# dtype: object

# %%
#Find the number of rows and columns using the shape property and the len( ) function.
a=df.shape
a
# Out:
# (30, 7)

# %%
len(df)
# Out:
# 30

# %%
#Display the first and last 10 rows.
df.head(10)
# Out:
#   Symbol                Company Exchange                 Industry  Date added  \
# 0    MMM                     3M     NYSE             Conglomerate  1976-08-09
# 1    AXP       American Express     NYSE       Financial services  1982-08-30
# 2   AMGN                  Amgen   NASDAQ  Pharmaceutical industry  2020-08-31
# 3   AAPL             Apple Inc.   NASDAQ   Information technology  2015-03-19
# 4     BA                 Boeing     NYSE    Aerospace and defense  1987-03-12
# 5    CAT       Caterpillar Inc.     NYSE  Construction and Mining  1991-05-06
# 6    CVX    Chevron Corporation     NYSE       Petroleum industry  2008-02-19
# 7   CSCO          Cisco Systems   NASDAQ   Information technology  2009-06-08
# 8     KO  The Coca-Cola Company     NYSE            Food industry  1987-03-12
# 9    DOW               Dow Inc.     NYSE        Chemical industry  2019-04-02
#
#                                    Notes Index weighting
# ...

# %%
df.tail(10)
# Out:
#    Symbol                   Company Exchange                        Industry  \
# 20    NKE                Nike, Inc.     NYSE                         Apparel
# 21     PG          Procter & Gamble     NYSE      Fast-moving consumer goods
# 22    CRM                Salesforce     NYSE          Information technology
# 23    TRV   The Travelers Companies     NYSE              Financial services
# 24    UNH        UnitedHealth Group     NYSE             Managed health care
# 25     VZ    Verizon Communications     NYSE               Telecommunication
# 26      V                 Visa Inc.     NYSE              Financial services
# 27    WBA  Walgreens Boots Alliance   NASDAQ                       Retailing
# 28    WMT                   Walmart     NYSE                       Retailing
# 29    DIS   The Walt Disney Company     NYSE  Broadcasting and entertainment
#
#     Date added Notes Index weighting
# 20  2013-09-20   NaN           2.58%
# 21  1932-05-26   NaN           2.64%
# ...

# %%
# Show the Company column.
df['Company']
# Out:
# 0                           3M
# 1             American Express
# 2                        Amgen
# 3                   Apple Inc.
# 4                       Boeing
# 5             Caterpillar Inc.
# 6          Chevron Corporation
# 7                Cisco Systems
# 8        The Coca-Cola Company
# 9                     Dow Inc.
# 10               Goldman Sachs
# 11              The Home Depot
# 12                   Honeywell
# 13                         IBM
# 14                       Intel
# 15           Johnson & Johnson
# 16              JPMorgan Chase
# 17                  McDonald's
# 18                 Merck & Co.
# 19                   Microsoft
# 20                  Nike, Inc.
# 21            Procter & Gamble
# 22                  Salesforce
# 23     The Travelers Companies
# 24          UnitedHealth Group
# 25      Verizon Communications
# 26                   Visa Inc.
# 27    Walgreens Boots Alliance
# 28                     Walmart
# 29     The Walt Disney Company
# ...

# %%
df[['Company','Industry']]
# Out:
#                      Company                        Industry
# 0                         3M                    Conglomerate
# 1           American Express              Financial services
# 2                      Amgen         Pharmaceutical industry
# 3                 Apple Inc.          Information technology
# 4                     Boeing           Aerospace and defense
# 5           Caterpillar Inc.         Construction and Mining
# 6        Chevron Corporation              Petroleum industry
# 7              Cisco Systems          Information technology
# 8      The Coca-Cola Company                   Food industry
# 9                   Dow Inc.               Chemical industry
# 10             Goldman Sachs              Financial services
# 11            The Home Depot                       Retailing
# 12                 Honeywell                    Conglomerate
# 13                       IBM          Information technology
# ...

# %%
df[df['Symbol'] == 'AAPL']
# Out:
#   Symbol     Company Exchange                Industry  Date added Notes  \
# 3   AAPL  Apple Inc.   NASDAQ  Information technology  2015-03-19   NaN
#
#   Index weighting
# 3           2.57%

# %%
#Show the Exchange for the row with the Symbol AAPL.
df[df['Symbol'] == 'AAPL']["Exchange"]
# Out:
# 3    NASDAQ
# Name: Exchange, dtype: object

# %%
#Sort (and show) the data by Industry, the Company.
df.sort_values(by=['Industry', 'Company'], ascending=[True,True])
# Out:
#    Symbol                   Company Exchange                        Industry  \
# 4      BA                    Boeing     NYSE           Aerospace and defense
# 20    NKE                Nike, Inc.     NYSE                         Apparel
# 29    DIS   The Walt Disney Company     NYSE  Broadcasting and entertainment
# 9     DOW                  Dow Inc.     NYSE               Chemical industry
# 0     MMM                        3M     NYSE                    Conglomerate
# 12    HON                 Honeywell   NASDAQ                    Conglomerate
# 5     CAT          Caterpillar Inc.     NYSE         Construction and Mining
# 21     PG          Procter & Gamble     NYSE      Fast-moving consumer goods
# 1     AXP          American Express     NYSE              Financial services
# 10     GS             Goldman Sachs     NYSE              Financial services
# 16    JPM            JPMorgan Chase     NYSE              Financial services
# ...

# %%
#Show the rows where Industry is Information Technology.
df[df['Industry'] == 'Information technology']
# Out:
#    Symbol        Company Exchange                Industry  Date added  \
# 3    AAPL     Apple Inc.   NASDAQ  Information technology  2015-03-19
# 7    CSCO  Cisco Systems   NASDAQ  Information technology  2009-06-08
# 13    IBM            IBM     NYSE  Information technology  1979-06-29
# 14   INTC          Intel   NASDAQ  Information technology  1999-11-01
# 19   MSFT      Microsoft   NASDAQ  Information technology  1999-11-01
# 22    CRM     Salesforce     NYSE  Information technology  2020-08-31
#
#                             Notes Index weighting
# 3                             NaN           2.57%
# 7                             NaN           1.00%
# 13  Also 1932-05-26 to 1939-03-04           2.59%
# 14                            NaN           1.25%
# 19                            NaN           4.98%
# 22                            NaN           4.45%

# %%
#11. Show the rows where Notes has a value (other than missing).
df[df['Notes'].notna()]
# Out:
#    Symbol                Company Exchange                Industry  Date added  \
# 0     MMM                     3M     NYSE            Conglomerate  1976-08-09
# 6     CVX    Chevron Corporation     NYSE      Petroleum industry  2008-02-19
# 8      KO  The Coca-Cola Company     NYSE           Food industry  1987-03-12
# 13    IBM                    IBM     NYSE  Information technology  1979-06-29
#
#                                     Notes Index weighting
# 0   As Minnesota Mining and Manufacturing           3.84%
# 6           Also 1930-07-18 to 1999-11-01           2.03%
# 8           Also 1932-05-26 to 1935-11-20           1.04%
# 13          Also 1932-05-26 to 1939-03-04           2.59%

# %%
#Create and display a Data Frame from the full Data Frame but excluding the Notes col
df.drop('Notes',axis = 1)
# Out:
#    Symbol                   Company Exchange                        Industry  \
# 0     MMM                        3M     NYSE                    Conglomerate
# 1     AXP          American Express     NYSE              Financial services
# 2    AMGN                     Amgen   NASDAQ         Pharmaceutical industry
# 3    AAPL                Apple Inc.   NASDAQ          Information technology
# 4      BA                    Boeing     NYSE           Aerospace and defense
# 5     CAT          Caterpillar Inc.     NYSE         Construction and Mining
# 6     CVX       Chevron Corporation     NYSE              Petroleum industry
# 7    CSCO             Cisco Systems   NASDAQ          Information technology
# 8      KO     The Coca-Cola Company     NYSE                   Food industry
# 9     DOW                  Dow Inc.     NYSE               Chemical industry
# 10     GS             Goldman Sachs     NYSE              Financial services
# ...

# %% [markdown]
# #The file Stock-Prices.csv has additional data, including Symbols and Prices. Use join() to
# augment the Data Frame with the Price data.

# %%
import pandas as pd
df1=pd.read_csv('C:\\Users\\hp\\Desktop\\da\\projects\\stock project\\Stock-Prices.csv')
df1
# Out:
#    Symbol   Price
# 0     MMM  223.34
# 1     AXP  176.22
# 2    AMGN  262.12
# 3    AAPL  137.07
# 4      BA  271.76
# 5     CAT  265.12
# 6     CVX  114.33
# 7    CSCO   58.23
# 8      KO   60.89
# 9     DOW   75.30
# 10     GS  409.46
# 11     HD  350.93
# 12    HON  254.53
# 13    IBM  158.39
# 14   INTC   62.89
# 15    JNJ  186.34
# 16    JPM  180.62
# 17    MCD  257.24
# 18    MRK   14.08
# 19   MSFT  274.81
# 20    NKE  150.11
# 21     PG  148.39
# 22    CRM  261.25
# 23    TRV  175.67
# 24    UNH  453.73
# 25     VZ   62.15
# 26      V  250.25
# 27    WBA   58.03
# 28    WMT  156.22
# 29    DIS  196.66

# %%
a=pd.merge(df,df1,how='outer')
a
# Out:
#    Symbol                   Company Exchange                        Industry  \
# 0    AAPL                Apple Inc.   NASDAQ          Information technology
# 1    AMGN                     Amgen   NASDAQ         Pharmaceutical industry
# 2     AXP          American Express     NYSE              Financial services
# 3      BA                    Boeing     NYSE           Aerospace and defense
# 4     CAT          Caterpillar Inc.     NYSE         Construction and Mining
# 5     CRM                Salesforce     NYSE          Information technology
# 6    CSCO             Cisco Systems   NASDAQ          Information technology
# 7     CVX       Chevron Corporation     NYSE              Petroleum industry
# 8     DIS   The Walt Disney Company     NYSE  Broadcasting and entertainment
# 9     DOW                  Dow Inc.     NYSE               Chemical industry
# 10     GS             Goldman Sachs     NYSE              Financial services
# ...
